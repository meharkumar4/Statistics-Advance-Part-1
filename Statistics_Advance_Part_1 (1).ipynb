# %% [markdown]
# # Statistics Advance Part 1

# %% [markdown]
# 1. What is a random variable in probability theory.
# - A random variable is a function that assigns a numerical value to each outcome in a sample space of a random experiment.
#
#
# 2. What are the types of random variables?
# - 🔢 Types of Random Variables:
#
# * **Discrete Random Variable**
#    - Takes **countable** values (like 0, 1, 2, 3...)
#    - Example: Number of goals in a football match
#
# *  **Continuous Random Variable**
#    - Takes **infinite/unlimited** values within a range (like 2.5, 3.14, etc.)
#    - Example: Height of a person, time, speed
#
#
#
# 3. What is the difference between discrete and continuous distributions?
# -
# ###  **Discrete vs Continuous Distributions**
#
# | Feature                        | **Discrete Distribution**                            | **Continuous Distribution**                             |
# |-------------------------------|------------------------------------------------------|---------------------------------------------------------|
# | **Type of Variable**          | Discrete Random Variable                            | Continuous Random Variable                             |
# | **Values Taken**              | Countable (like 0, 1, 2, 3...)                      | Infinite (any value within a range, like 2.45, 3.7...) |
# | **Probability is assigned to**| Specific values                                     | A range of values                                      |
# | **Example**                   | Tossing coins, rolling dice                         | Heights, weights, time, temperature                    |
# | **Function used**             | **Probability Mass Function (PMF)**                 | **Probability Density Function (PDF)**                 |
#
#
#
#
#
#
# 4. What are probability distribution functions (PDF)?
# - A Probability Distribution Function describes how probabilities are distributed over the values of a random variable.
#
#
#
#
# 5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
# - The Probability Distribution Function (PDF) tells us how the probabilities are distributed at individual points (for discrete variables using PMF) or the density of probability at specific values (for continuous variables using PDF). In contrast, the Cumulative Distribution Function (CDF) gives the total probability up to a certain value. It shows the probability that a random variable is less than or equal to a certain number. While the PDF shows “how likely” a specific value is, the CDF shows the accumulated probability from the start up to that value. So, the CDF is like a running total of probabilities and always increases from 0 to 1, making it super useful when you want to know the overall chance up to a point, not just at a point.
#
#
# 6. What is a discrete uniform distribution?
# - A Discrete Uniform Distribution is a type of discrete probability distribution where all outcomes are equally likely.
#
#
# 7.  What are the key properties of a Bernoulli distribution?
# -
# ###  **Key Properties:**
#
# | Property                     | Description                                                                 |
# |-----------------------------|-----------------------------------------------------------------------------|
# | **Outcomes**                | 0 (Failure) or 1 (Success)                                                  |
# | **Parameter**               | \( p \) = Probability of success (0 ≤ p ≤ 1)                                |
# | **Mean (Expected Value)**   | \( E[X] = p \)                                                              |
# | **Variance**                | \( Var(X) = p(1 - p) \)                                                     |
# | **PMF (Probability)**       | \[ P(X = x) = p^x (1 - p)^{1 - x} \] for x ∈ {0, 1}                         |
# | **Uses**                    | Used for binary outcomes: success/failure, yes/no, win/lose                 |
#
#
#
#
#
# 8. What is the binomial distribution, and how is it used in probability/
# - A Binomial Distribution models the number of successes in a fixed number of independent trials, where each trial has only two possible outcomes:
# ✅ Success or ❌ Failure.
#
# It’s basically a series of Bernoulli trials repeated n times. Used when you want to find the probability of getting a certain number of successes out of a fixed number of trials.
#
#
# 9. What is the Poisson distribution and where is it applied?
# - The Poisson Distribution is used to model the number of times an event occurs in a fixed interval of time, space, area, or volume — when events happen randomly and independently.
#
# It’s ideal when events are rare, but you still want to predict how often they’ll happen.
#
#
#
# 10. What is a continuous uniform distribution?
# - A Continuous Uniform Distribution is a probability distribution where all values within a certain range are equally likely to occur. It’s like a perfectly fair roulette wheel — every number has the same chance.
#
#
#
#
# 11. What are the characteristics of a normal distribution/
# - It's a **bell-shaped** curve that shows how values are **distributed around the mean** in many real-life situations (like height, test scores, etc.).
#
#
#
# ###  **Key Characteristics:**
#
# 1. **Symmetrical Shape**
#    - The curve is perfectly **symmetric about the mean**
#    - Left and right sides are mirror images
#
# 2. **Mean = Median = Mode**
#    - All three are located at the **center** of the distribution
#
# 3. **Bell-Shaped Curve**
#    - The curve rises to a peak at the mean and **tapers off** on both sides
#
# 4. **Defined by Two Parameters:**
#    - **μ (mu)** = Mean → center of the distribution
#    - **σ (sigma)** = Standard deviation → spread or width of the curve
#
# 5. **68-95-99.7 Rule (Empirical Rule)**
#    - ~68% of data falls within **±1σ**
#    - ~95% within **±2σ**
#    - ~99.7% within **±3σ**
#
# 6. **Total Area = 1**
#    - The total area under the curve represents the **entire probability** and equals **1**
#
# 7. **Asymptotic**
#    - The tails never touch the x-axis completely; they **extend to infinity**
#
#
#
#
# 12. What is the standard normal distribution, and why is it important?
# - The **Standard Normal Distribution** is a **special case** of the normal distribution where:
#
# - **Mean (μ) = 0**
# - **Standard deviation (σ) = 1**
#
# It's still the same bell-shaped curve, just **centered at 0** and **measured in standard deviations**.
#
# ### **Why is it Important?**
#
# Because it makes **calculations and comparisons easy**!
# Instead of working with different scales (heights, marks, weights), we **convert values into "Z-scores"** using:
#
# \[
# Z = \frac{X - \mu}{\sigma}
# \]
#
# Where:
# - \(X\) = raw score
# - \(\mu\) = mean
# - \(\sigma\) = standard deviation
# - \(Z\) = how many standard deviations \(X\) is from the mean
#
#
#
#
# 13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?
# - The Central Limit Theorem (CLT) says:
#
# If you take a large number of random samples from any population (with any shape), the distribution of the sample means will approximate a normal distribution — no matter what the original population looks like, as long as the sample size is large enough (usually n ≥ 30 is good).
#
# ### &#x20; **Why is it so Important?**
#
# Because it’s the **foundation** of most statistical methods. Here's why:
#
# 1.  **Enables use of the normal distribution**
#
#    - Even if the data is not normal, the **mean of samples** will be!
#
# 2.  **Allows accurate estimation**
#
#    - Lets us calculate **confidence intervals**, **Z-scores**, and do **hypothesis testing** — even with non-normal data.
#
# 3.  **Supports real-world decision-making**
#
#    - In business, economics, medicine, psychology — CLT powers predictions, analysis, and quality control.
#
#
#
#
#
# 14. How does the Central Limit Theorem relate to the normal distribution/
# - The Central Limit Theorem explains why the normal distribution is so commonly used in statistics.
#
# Even if the original population is not normally distributed, the distribution of the sample means (i.e., the averages of repeated random samples) will tend to become normal as:
#
# * The sample size increases (typically n ≥ 30 is good)
#
# * The samples are independent and randomly selected
#
#
#
# 15. What is the application of Z statistics in hypothesis testing?
# - The Z-statistic (or Z-score) is a value that tells you how many standard deviations a data point (or sample mean) is from the population mean — under the assumption that the null hypothesis is true.
#
# It’s used in Z-tests, which are a type of hypothesis test when the population standard deviation is known and the sample size is reasonably large (n ≥ 30).
#
#
#
#
# 16. How do you calculate a Z-score, and what does it represent?
# -
#
#
# ###  **How to Calculate a Z-Score**
#
# $$
# Z = \frac{X - \mu}{\sigma}
# $$
#
# Where:
#
# - \(X\) = your data point (value you observed)
# - \(\mu\) = population mean
# - \(\sigma\) = population standard deviation
#
#
#
# ###  **What Does a Z-Score Represent?**
#
# A **Z-score tells you how many standard deviations a value is from the mean**.
#
# | Z-Score | What It Means                           |
# | ------- | --------------------------------------- |
# | 0       | Right at the mean                       |
# | +1      | 1 standard deviation **above** the mean |
# | -1      | 1 standard deviation **below** the mean |
# | +2      | 2 SDs above (unusual high)              |
# | -2      | 2 SDs below (unusual low)               |
#
#
#
#
# 17. What are point estimates and interval estimates in statistics?
# - * A point estimate is a single value that serves as the best guess of a population parameter (like mean or proportion).
#
#
# * An interval estimate gives a range of values (called a confidence interval) that is likely to contain the true population parameter — along with a confidence level (like 95%).
#
#
#
# 18. What is the significance of confidence intervals in statistical analysis?
# - A confidence interval (CI) provides a range of values that’s likely to include the true population parameter, like a mean or proportion — based on your sample data.
#
#
#
# ###  **Why Are They So Important?**
#
# 1.  **They Show Precision**
#
#    - A **narrower interval** = more precise estimate
#    - A **wider interval** = more uncertainty
#
# 2.  **They Reflect Confidence**
#
#    - A 95% CI means: “If we repeated this process many times, **95% of the intervals** would capture the true value.”
#
# 3.  **They Go Beyond Point Estimates**
#
#    - Instead of saying “the average is 50,” you say:\
#      “I’m 95% confident the average is **between 47 and 53**.”
#
# 4.  **They Help Avoid False Certainty**
#
#    - CI shows **margin of error**, not just a single guess
#    - That makes decisions **data-driven**, not assumptions-based
#
# 5.  **They Aid in Hypothesis Testing**
#
#    - If the CI **does not contain** the hypothesized value (like population mean), it supports **rejecting the null hypothesis**
#
#
#
# 19. What is the relationship between a Z-score and a confidence interval?
# - A Z-score is directly used to construct a confidence interval (CI) when the population standard deviation (σ) is known and the sample size is large.
#
#
#
#
# 20. How are Z-scores used to compare different distributions?
# -
#
# A **Z-score standardizes values** by converting them into a **common scale** — measured in **standard deviations from the mean**.
#
# \[
# Z = \frac{X - \mu}{\sigma}
# \]
#
# This makes it possible to **compare scores from different datasets**, regardless of their original units or scales.
#
#
#
#
# 21. What are the assumptions for applying the Central Limit Theorem?
# -
# ### ⚙️ **Assumptions for Applying the Central Limit Theorem (CLT):**
#
# 1.  **Random Sampling**
#    - Data must be selected randomly.
#
# 2.  **Independence**
#    - Observations should not influence each other.
#
# 3.  **Large Sample Size**
#    - For non-normal populations, use **n ≥ 30**.
#
# 4.  **Finite Mean and Variance**
#    - The population should have defined, finite **μ** and **σ²**.
#
#
#
#
# 22. What is the concept of expected value in a probability distribution?
# - The **expected value (EV)** is the **mean** of a random variable — it tells you what value to expect **on average** if an experiment is repeated many times.
#
#
#
# ###  **Formula for Expected Value**
#
# For **discrete random variables**:
#
# \[
# E(X) = \sum [x_i \cdot P(x_i)]
# \]
#
# Where:
# - \( x_i \) = value of the outcome
# - \( P(x_i) \) = probability of that outcome
# - Multiply each outcome by its probability and add them up
#
#
#
#
# 23. How does a probability distribution relate to the expected outcome of a random variable?
# - A probability distribution tells you all the possible values a random variable can take — and how likely each one is.
#
# The expected outcome (or expected value) is the weighted average of these values — where the weights are the probabilities from the distribution.

# %% [markdown]
# # Practical

# %%
#1. Write a Python program to generate a random variable and display its value?

import random

# Define the possible outcomes (1 to 6 for a die)
outcomes = [1, 2, 3, 4, 5, 6]

# Generate a random outcome
random_variable = random.choice(outcomes)

# Display the result
print(f"The random variable generated is: {random_variable}")
# Out:
# The random variable generated is: 5

# %%
# 2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF)


import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Parameters for the discrete uniform distribution
low = 1     # inclusive lower bound
high = 7    # exclusive upper bound, so values will be [1, 2, 3, 4, 5, 6]

# Create the discrete uniform distribution
dist = randint(low, high)

# Values to plot
x = np.arange(low, high)
pmf_values = dist.pmf(x)

# Plot the PMF
plt.figure(figsize=(8, 5))
# Remove or comment out 'use_line_collection=True' for older versions of Matplotlib
#plt.stem(x, pmf_values, use_line_collection=True)
plt.stem(x, pmf_values)  # For older versions of Matplotlib
plt.title('PMF of Discrete Uniform Distribution (1 to 6)')
plt.xlabel('x')
plt.ylabel('P(X = x)')
plt.grid(True)
plt.show()

# %%
#3 Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution>
def bernoulli_pdf(x, p):
    """
    Calculate the PDF of a Bernoulli distribution.

    Parameters:
    x : int (0 or 1)
        The outcome (0 or 1).
    p : float (0 <= p <= 1)
        The probability of success (X = 1).

    Returns:
    float
        Probability of observing x in a Bernoulli(p) distribution.
    """
    if x not in [0, 1]:
        raise ValueError("x must be 0 or 1")
    if not (0 <= p <= 1):
        raise ValueError("p must be between 0 and 1")

    return p**x * (1 - p)**(1 - x)

# Example usage
print("P(X=0):", bernoulli_pdf(0, 0.7))  # Output: 0.3
print("P(X=1):", bernoulli_pdf(1, 0.7))  # Output: 0.7
# Out:
# P(X=0): 0.30000000000000004
# P(X=1): 0.7

# %%
#4 Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.
import numpy as np
import matplotlib.pyplot as plt

# Parameters
n = 10       # number of trials
p = 0.5      # probability of success
size = 10000 # number of simulations

# Simulate binomial distribution
data = np.random.binomial(n, p, size)

# Plot histogram
plt.figure(figsize=(8, 5))
plt.hist(data, bins=np.arange(0, n+2) - 0.5, density=True, edgecolor='black')
plt.title(f'Binomial Distribution Histogram (n={n}, p={p})')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.xticks(range(n+1))
plt.grid(True)
plt.show()

# %%
#5 Create a Poisson distribution and visualize it using Python
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Parameter
lambda_val = 4  # average rate (λ)
x = np.arange(0, 15)  # range of values to plot

# PMF of Poisson distribution
pmf = poisson.pmf(x, mu=lambda_val)

# Plot
plt.figure(figsize=(8, 5))
# Remove 'use_line_collection=True' for older versions of Matplotlib
# plt.

# %%
#6 Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Parameters
low = 1     # inclusive lower bound
high = 7    # exclusive upper bound (1 to 6)
x = np.arange(low, high + 1)

# Create the discrete uniform distribution
dist = randint(low, high)

# Calculate CDF
cdf_values = dist.cdf(x)

# Plot the CDF
plt.figure(figsize=(8, 5))
plt.step(x, cdf_values, where='post', label='CDF', color='blue')
plt.title('CDF of Discrete Uniform Distribution (1 to 6)')
plt.xlabel('x')
plt.ylabel('P(X ≤ x)')
plt.xticks(x)
plt.grid(True)
plt.legend()
plt.show()

# %%
#7 Generate a continuous uniform distribution using NumPy and visualize it
import numpy as np
import matplotlib.pyplot as plt

# Parameters
low = 0     # lower bound (inclusive)
high = 10   # upper bound (exclusive)
size = 10000  # number of samples

# Generate samples from a continuous uniform distribution
data = np.random.uniform(low, high, size)

# Plot histogram
plt.figure(figsize=(8, 5))
plt.hist(data, bins=50, density=True, edgecolor='black', alpha=0.7)
plt.title(f'Continuous Uniform Distribution U({low}, {high})')
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %%
#8  Simulate data from a normal distribution and plot its histogram
import numpy as np
import matplotlib.pyplot as plt

# Parameters
mean = 0       # Mean of the distribution
std_dev = 1    # Standard deviation
size = 10000   # Number of samples

# Generate normal distribution data
data = np.random.normal(mean, std_dev, size)

# Plot histogram
plt.figure(figsize=(8, 5))
plt.hist(data, bins=50, density=True, color='skyblue', edgecolor='black', alpha=0.7)
plt.title(f'Normal Distribution Histogram (μ = {mean}, σ = {std_dev})')
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %%
#9 Write a Python function to calculate Z-scores from a dataset and plot them
import numpy as np
import matplotlib.pyplot as plt

def calculate_and_plot_zscores(data):
    """
    Calculate Z-scores for a dataset and plot them.

    Parameters:
    data : list or np.array
        The input dataset.
    """
    data = np.array(data)
    mean = np.mean(data)
    std = np.std(data)

    if std == 0:
        raise ValueError("Standard deviation is zero. Z-scores cannot be calculated.")

    z_scores = (data - mean) / std

    # Plotting
    plt.figure(figsize=(10, 5))
    plt.plot(z_scores, marker='o', linestyle='-', color='blue', label='Z-score')
    plt.axhline(0, color='gray', linestyle='--')
    plt.axhline(1, color='green', linestyle='--', label='1 Std Dev')
    plt.axhline(-1, color='green', linestyle='--')
    plt.title('Z-scores of Dataset')
    plt.xlabel('Data Index')
    plt.ylabel('Z-score')
    plt.grid(True)
    plt.legend()
    plt.show()

    return z_scores

# Example usage
sample_data = np.random.normal(50, 10, 100)
z = calculate_and_plot_zscores(sample_data)

# %%
#10  Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution
import numpy as np
import matplotlib.pyplot as plt

# Parameters
population_size = 100000
sample_size = 30
num_samples = 1000

# Step 1: Generate non-normal population data (Exponential distribution)
population = np.random.exponential(scale=2.0, size=population_size)

# Step 2: Collect sample means
sample_means = []
for _ in range(num_samples):
    sample = np.random.choice(population, size=sample_size)
    sample_means.append(np.mean(sample))

# Step 3: Plot histogram of sample means
plt.figure(figsize=(10, 5))

plt.hist(sample_means, bins=50, density=True, color='skyblue', edgecolor='black', alpha=0.7)
plt.title(f'Central Limit Theorem Demonstration\n(Sample size = {sample_size}, Samples = {num_samples})')
plt.xlabel('Sample Mean')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %%
#15 Simulate multiple samples from a normal distribution and verify the Central Limit Theorem
import numpy as np
import matplotlib.pyplot as plt

# Parameters
mean = 100
std_dev = 15
sample_size = 50
num_samples = 1000

# Step 1: Simulate sample means from a normal distribution
sample_means = []
for _ in range(num_samples):
    sample = np.random.normal(mean, std_dev, sample_size)
    sample_mean = np.mean(sample)
    sample_means.append(sample_mean)

# Step 2: Plot histogram of sample means
plt.figure(figsize=(10, 5))
plt.hist(sample_means, bins=40, density=True, color='lightgreen', edgecolor='black', alpha=0.7)
plt.title(f'CLT with Normally Distributed Data\n(Sample Size = {sample_size}, Samples = {num_samples})')
plt.xlabel('Sample Mean')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %%
#16 Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1)
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal_distribution():
    """
    Calculate and plot the standard normal distribution (mean=0, std=1).
    """
    # Generate x values from -4 to 4
    x = np.linspace(-4, 4, 1000)

    # Calculate the standard normal PDF
    pdf = norm.pdf(x, loc=0, scale=1)

    # Plot
    plt.figure(figsize=(8, 5))
    plt.plot(x, pdf, color='blue', label='Standard Normal PDF')
    plt.fill_between(x, pdf, alpha=0.2)
    plt.title('Standard Normal Distribution (μ = 0, σ = 1)')
    plt.xlabel('x')
    plt.ylabel('Probability Density')
    plt.grid(True)
    plt.legend()
    plt.show()

# Example usage
plot_standard_normal_distribution()

# %%
#17 Generate random variables and calculate their corresponding probabilities using the binomial distribution
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# Binomial parameters
n = 10     # number of trials
p = 0.5    # probability of success
size = 1000  # number of random variables

# Step 1: Generate random binomial variables
data = np.random.binomial(n, p, size)

# Step 2: Count occurrences of each outcome
values, counts = np.unique(data, return_counts=True)

# Step 3: Calculate PMF values for each unique outcome
pmf_values = binom.pmf(values, n, p)

# Step 4: Normalize counts to get empirical probabilities
empirical_probs = counts / size

# Step 5: Plot
plt.figure(figsize=(10, 5))
plt.bar(values - 0.2, empirical_probs, width=0.4, label='Empirical Probabilities', alpha=0.7)
plt.bar(values + 0.2, pmf_values, width=0.4, label='Binomial PMF (Theoretical)', alpha=0.7)
plt.title(f'Binomial Distribution (n={n}, p={p})\nEmpirical vs Theoretical Probabilities')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.xticks(values)
plt.grid(True)
plt.legend()
plt.show()

# %%
#18 Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_z_score(x, mean, std):
    z = (x - mean) / std
    return z

def plot_standard_normal_with_z(z):
    x_vals = np.linspace(-4, 4, 1000)
    y_vals = norm.pdf(x_vals)

    plt.figure(figsize=(10, 5))
    plt.plot(x_vals, y_vals, label='Standard Normal PDF', color='blue')
    plt.fill_between(x_vals, y_vals, where=(x_vals <= z), color='orange', alpha=0.5, label=f'Z ≤ {z:.2f}')
    plt.axvline(z, color='red', linestyle='--', label=f'Z = {z:.2f}')
    plt.title('Z-score Compared to Standard Normal Distribution')
    plt.xlabel('Z-value')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True)
    plt.show()

# Example values
data_point = 115
mean = 100
std = 15

# Step 1: Calculate Z-score
z_score = calculate_z_score(data_point, mean, std)
print(f"Z-score for X = {data_point}: {z_score:.2f}")

# Step 2: Plot comparison with standard normal distribution
plot_standard_normal_with_z(z_score)
# Out:
# Z-score for X = 115: 1.00

# %%
#19  Implement hypothesis testing using Z-statistics for a sample dataset
import numpy as np
from scipy.stats import norm

def z_test(sample_data, population_mean, population_std, alpha=0.05):
    sample_size = len(sample_data)
    sample_mean = np.mean(sample_data)

    # Step 1: Calculate Z-statistic
    z = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

    # Step 2: Calculate p-value (two-tailed test)
    p_value = 2 * (1 - norm.cdf(abs(z)))

    # Step 3: Make a decision
    reject_null = p_value < alpha

    # Print results
    print(f"Sample Mean = {sample_mean:.2f}")
    print(f"Z-statistic = {z:.4f}")
    print(f"P-value = {p_value:.4f}")
    if reject_null:
        print("🚨 Reject the null hypothesis (H₀). Significant difference found.")
    else:
        print("✅ Fail to reject the null hypothesis (H₀). No significant difference.")

# Example usage
np.random.seed(42)
sample = np.random.normal(loc=102, scale=15, size=50)  # sample data with mean around 102
population_mean = 100
population_std = 15

z_test(sample, population_mean, population_std)
# Out:
# Sample Mean = 98.62
# Z-statistic = -0.6515
# P-value = 0.5147
# ✅ Fail to reject the null hypothesis (H₀). No significant difference.

# %%
#20 Create a confidence interval for a dataset using Python and interpret the result
import numpy as np
from scipy.stats import norm

def confidence_interval(data, confidence=0.95):
    sample_mean = np.mean(data)
    sample_std = np.std(data, ddof=1)  # Sample standard deviation
    n = len(data)

    z_score = norm.ppf((1 + confidence) / 2)
    margin_of_error = z_score * (sample_std / np.sqrt(n))

    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    print(f"Sample Mean: {sample_mean:.2f}")
    print(f"{int(confidence*100)}% Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")
    return (lower_bound, upper_bound)

# Example usage
np.random.seed(1)
sample_data = np.random.normal(loc=100, scale=15, size=50)
confidence_interval(sample_data)
# Out:
# Sample Mean: 99.62
# 95% Confidence Interval: (95.55, 103.69)
# (np.float64(95.54507712046961), np.float64(103.68947743930087))

# %%
#21 Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean
import numpy as np
from scipy.stats import norm

def generate_normal_data_and_ci(mean=100, std_dev=15, size=50, confidence=0.95):
    # Step 1: Generate data
    np.random.seed(42)
    data = np.random.normal(loc=mean, scale=std_dev, size=size)

    # Step 2: Calculate sample statistics
    sample_mean = np.mean(data)
    sample_std = np.std(data, ddof=1)

    # Step 3: Compute margin of error
    z_score = norm.ppf((1 + confidence) / 2)
    margin_of_error = z_score * (sample_std / np.sqrt(size))

    # Step 4: Confidence interval
    lower = sample_mean - margin_of_error
    upper = sample_mean + margin_of_error

    print(f"Sample Mean: {sample_mean:.2f}")
    print(f"{int(confidence*100)}% Confidence Interval: ({lower:.2f}, {upper:.2f})")
    return data, (lower, upper)

# Example usage
data, ci = generate_normal_data_and_ci()
# Out:
# Sample Mean: 96.62
# 95% Confidence Interval: (92.74, 100.50)

# %%
#22 Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters of the normal distribution
mean = 100
std_dev = 15

# Generate x values
x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 1000)

# Calculate PDF values
pdf = norm.pdf(x, loc=mean, scale=std_dev)

# Plot
plt.figure(figsize=(10, 5))
plt.plot(x, pdf, label=f'N({mean}, {std_dev}²)', color='blue')
plt.fill_between(x, pdf, alpha=0.3, color='skyblue')
plt.title('Probability Density Function (PDF) of Normal Distribution')
plt.xlabel('x')
plt.ylabel('Density')
plt.grid(True)
plt.legend()
plt.show()

# %%
#23  Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Parameters
lambda_val = 5  # average number of events
x = np.arange(0, 15)  # possible values of k

# Calculate CDF values
cdf = poisson.cdf(x, mu=lambda_val)

# Print CDF for a specific value
k = 7
print(f"P(X ≤ {k}) when λ = {lambda_val} is: {poisson.cdf(k, mu=lambda_val):.4f}")

# Plotting the CDF
plt.figure(figsize=(10, 5))
plt.step(x, cdf, where='post', label='Poisson CDF', color='purple')
plt.scatter(x, cdf, color='black')
plt.title(f'Cumulative Distribution Function of Poisson(λ = {lambda_val})')
plt.xlabel('x')
plt.ylabel('Cumulative Probability')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# P(X ≤ 7) when λ = 5 is: 0.8666

# %%
#24 Simulate a random variable using a continuous uniform distribution and calculate its expected value
import numpy as np

# Parameters of the uniform distribution
a = 10   # lower bound
b = 30   # upper bound
n = 10000  # number of samples

# Simulate random variable
samples = np.random.uniform(low=a, high=b, size=n)

# Calculate sample mean (empirical expected value)
sample_mean = np.mean(samples)

# Theoretical expected value
expected_value = (a + b) / 2

# Results
print(f"Theoretical Expected Value: {expected_value:.2f}")
print(f"Empirical Mean from {n} samples: {sample_mean:.2f}")
# Out:
# Theoretical Expected Value: 20.00
# Empirical Mean from 10000 samples: 19.89

# %%
#25 Write a Python program to compare the standard deviations of two datasets and visualize the difference
import numpy as np
import matplotlib.pyplot as plt

# Generate two datasets
np.random.seed(42)
data1 = np.random.normal(loc=50, scale=5, size=1000)   # smaller spread
data2 = np.random.normal(loc=50, scale=15, size=1000)  # larger spread

# Calculate standard deviations
std1 = np.std(data1, ddof=1)
std2 = np.std(data2, ddof=1)

# Print comparison
print(f"Standard Deviation of Dataset 1: {std1:.2f}")
print(f"Standard Deviation of Dataset 2: {std2:.2f}")

# Visualize
plt.figure(figsize=(10, 5))
plt.hist(data1, bins=30, alpha=0.6, label=f'Dataset 1 (σ={std1:.2f})', color='blue')
plt.hist(data2, bins=30, alpha=0.6, label=f'Dataset 2 (σ={std2:.2f})', color='red')
plt.title("Comparison of Standard Deviations Between Two Datasets")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Standard Deviation of Dataset 1: 4.90
# Standard Deviation of Dataset 2: 14.96

# %%
#26 Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution

import numpy as np

# Step 1: Generate data from a normal distribution
np.random.seed(42)
data = np.random.normal(loc=100, scale=15, size=1000)

# Step 2: Calculate Range
range_val = np.max(data) - np.min(data)

# Step 3: Calculate IQR
q1 = np.percentile(data, 25)
q3 = np.percentile(data, 75)
iqr = q3 - q1

# Step 4: Display results
print(f"Range: {range_val:.2f}")
print(f"Interquartile Range (IQR): {iqr:.2f}")
print(f"Q1 (25th percentile): {q1:.2f}")
print(f"Q3 (75th percentile): {q3:.2f}")
# Out:
# Range: 106.41
# Interquartile Range (IQR): 19.43
# Q1 (25th percentile): 90.29
# Q3 (75th percentile): 109.72

# %%
#27 Implement Z-score normalization on a dataset and visualize its transformation
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Generate dataset
np.random.seed(42)
data = np.random.normal(loc=50, scale=10, size=1000)

# Step 2: Z-score normalization
mean = np.mean(data)
std = np.std(data)
z_scores = (data - mean) / std

# Step 3: Print a few results
print(f"Original Mean: {mean:.2f}, Original Std Dev: {std:.2f}")
print(f"Normalized Mean: {np.mean(z_scores):.2f}, Std Dev: {np.std(z_scores):.2f}")

# Step 4: Visualization
plt.figure(figsize=(12, 5))

# Original data histogram
plt.subplot(1, 2, 1)
plt.hist(data, bins=30, color='skyblue', edgecolor='black')
plt.title('Original Data')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)

# Z-score normalized data histogram
plt.subplot(1, 2, 2)
plt.hist(z_scores, bins=30, color='salmon', edgecolor='black')
plt.title('Z-score Normalized Data')
plt.xlabel('Z-score')
plt.ylabel('Frequency')
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Original Mean: 50.19, Original Std Dev: 9.79
# Normalized Mean: -0.00, Std Dev: 1.00

# %%
#28 Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution
import numpy as np
from scipy.stats import skew, kurtosis

def analyze_distribution_skew_kurt(mean=0, std_dev=1, size=1000):
    # Step 1: Generate data
    data = np.random.normal(loc=mean, scale=std_dev, size=size)

    # Step 2: Calculate skewness and kurtosis
    skew_val = skew(data)
    kurt_val = kurtosis(data, fisher=False)  # Fisher=False gives Pearson kurtosis (normal = 3)

    # Step 3: Display results
    print(f"Skewness: {skew_val:.4f}")
    print(f"Kurtosis: {kurt_val:.4f}")
    return skew_val, kurt_val

# Example usage
analyze_distribution_skew_kurt()
# Out:
# Skewness: -0.0493
# Kurtosis: 3.0521
# (np.float64(-0.049321773965299257), np.float64(3.05211754569784))
